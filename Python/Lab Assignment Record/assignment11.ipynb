# %%
# Absolute imports
from shapes.circle import Circle
from shapes.rectangle import Rectangle

c = Circle(5)
r = Rectangle(4, 6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())
# Out:
# Addition: 30
# Subtraction: 10
# Addition: 15
# Subtraction: 5

# %%
#Call Relative Impot

from shapes.utils import show_areas

show_areas()
